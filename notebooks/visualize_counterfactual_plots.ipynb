# %%
import pandas as pd

# %%
path = '../data/predictions/val_aids_counterfactual_statistics.csv'
df = pd.read_csv(path)

# %%
df
# Out:
#      Unnamed: 0   density  connected compenents  max-shortest path  \
# 0             0  0.222222                     1                  5
# 1             1  0.179487                     1                  6
# 2             2  0.179487                     1                  6
# 3             3  0.222222                     1                  5
# 4             4  0.222222                     1                  5
# ..          ...       ...                   ...                ...
# 158         158  0.166667                     1                  7
# 159         159  0.166667                     1                  9
# 160         160  0.250000                     1                  4
# 161         161  0.222222                     1                  5
# 162         162  0.222222                     1                  5
#
#      GED (Fidelity)  Absolute Difference (Validity)  \
# 0              15.0                        0.053768
# 1              10.0                        0.301335
# ...

# %%
# Max and min values
mins = df.min()
maxs = df.max()

# %%
# During evaluation bins should be created based on 1) latent euclidiean distance and 2) Latent Cossimilarity.
# The mean and standard deviation of each bin should be calculated.
# A plot should be created showing
