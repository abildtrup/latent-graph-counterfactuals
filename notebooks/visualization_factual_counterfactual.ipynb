# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy

# %% [markdown]
# ## Aids

# %%
prefix = 'val_aids'
folder = f'/home/andab/work/counterfactual_graph_generation/data/predictions/{prefix}_distribution_evaluation/'

mode = 'node_count'
den_cf=pd.read_csv(folder + f'{prefix}_counterfactual_{mode}.csv')
den_f=pd.read_csv(folder + f'{prefix}_factual_{mode}.csv')

mode = 'shannon_entropy'
se_cf=pd.read_csv(folder + f'{prefix}_counterfactual_{mode}.csv')
se_f=pd.read_csv(folder + f'{prefix}_factual_{mode}.csv')

mode = 'densities'
density_cf=pd.read_csv(folder + f'{prefix}_counterfactual_{mode}.csv')
density_f=pd.read_csv(folder + f'{prefix}_factual_{mode}.csv')

# %%
fig, axs = plt.subplots(3,3)
fig.set_size_inches(15,15)

###################################### Aids ############################################
# Node count
den_f[den_f['prediction']==1].Number_of_nodes.plot(kind='density',alpha=0.8, color='green',linestyle='--', label='Factual Label 1', ax=axs[0,0])
den_cf[den_cf['prediction']==1].Number_of_nodes.plot(kind='density',alpha=0.8, color='green',label='Counterfactual Label 1', ax=axs[0,0])
den_f[den_f['prediction']==0].Number_of_nodes.plot(kind='density',alpha=0.8, color='blue',linestyle='--', label='Factual Label 0', ax=axs[0,0])
den_cf[den_cf['prediction']==0].Number_of_nodes.plot(kind='density',alpha=0.8,xlabel='Nr Nodes',color='blue',label='Counterfactual Label 0', ax=axs[0,0], title='Node Count Distribution')

# Shannon Entropy
se_f[se_f['target']==1].iloc[:,1].plot(kind='density',alpha=0.8, color='green',linestyle='--', label='Factual Label 1', ax=axs[0,1])
se_cf[se_cf['target']==1].iloc[:,1].plot(kind='density',alpha=0.8, color='green',label='Counterfactual Label 1', ax=axs[0,1])
se_f[se_f['target']==0].iloc[:,1].plot(kind='density',alpha=0.8, color='blue',linestyle='--', label='Factual Label 0', ax=axs[0,1])
se_cf[se_cf['target']==0].iloc[:,1].plot(kind='density',alpha=0.8,color='blue',label='Counterfactual Label 0', ax=axs[0,1], title='Shannon Entropy Distribution')

# Density
density_f[density_f['target']==1].iloc[:,1].plot(kind='density',alpha=0.8, color='green',linestyle='--', label='Factual Label 1', ax=axs[0,2])
density_cf[density_cf['target']==1].iloc[:,1].plot(kind='density',alpha=0.8, color='green',label='Counterfactual Label 1', ax=axs[0,2])
density_f[density_f['target']==0].iloc[:,1].plot(kind='density',alpha=0.8, color='blue',linestyle='--', label='Factual Label 0', ax=axs[0,2])
density_cf[density_cf['target']==0].iloc[:,1].plot(kind='density',alpha=0.8,color='blue',label='Counterfactual Label 0', ax=axs[0,2], title='Graph Density Distribution')

###################################### Mutagenicity ############################################
prefix = 'val_mutagenicity'
folder = f'/home/andab/work/counterfactual_graph_generation/data/predictions/{prefix}_distribution_evaluation/'

mode = 'node_count'
den_cf=pd.read_csv(folder + f'{prefix}_counterfactual_{mode}.csv')
den_f=pd.read_csv(folder + f'{prefix}_factual_{mode}.csv')

mode = 'shannon_entropy'
se_cf=pd.read_csv(folder + f'{prefix}_counterfactual_{mode}.csv')
se_f=pd.read_csv(folder + f'{prefix}_factual_{mode}.csv')

mode = 'densities'
density_cf=pd.read_csv(folder + f'{prefix}_counterfactual_{mode}.csv')
density_f=pd.read_csv(folder + f'{prefix}_factual_{mode}.csv')

# Node count
den_f[den_f['prediction']==1].Number_of_nodes.plot(kind='density',alpha=0.8, color='green',linestyle='--', label='Factual Label 1', ax=axs[1,0])
den_cf[den_cf['prediction']==1].Number_of_nodes.plot(kind='density',alpha=0.8, color='green',label='Counterfactual Label 1', ax=axs[1,0])
den_f[den_f['prediction']==0].Number_of_nodes.plot(kind='density',alpha=0.8, color='blue',linestyle='--', label='Factual Label 0', ax=axs[1,0])
den_cf[den_cf['prediction']==0].Number_of_nodes.plot(kind='density',alpha=0.8,xlabel='Nr Nodes',color='blue',label='Counterfactual Label 0', ax=axs[1,0])

# Shannon Entropy
se_f[se_f['target']==1].iloc[:,1].plot(kind='density',alpha=0.8, color='green',linestyle='--', label='Factual Label 1', ax=axs[1,1])
se_cf[se_cf['target']==1].iloc[:,1].plot(kind='density',alpha=0.8, color='green',label='Counterfactual Label 1', ax=axs[1,1])
se_f[se_f['target']==0].iloc[:,1].plot(kind='density',alpha=0.8, color='blue',linestyle='--', label='Factual Label 0', ax=axs[1,1])
se_cf[se_cf['target']==0].iloc[:,1].plot(kind='density',alpha=0.8,color='blue',label='Counterfactual Label 0', ax=axs[1,1])

# Density
density_f[density_f['target']==1].iloc[:,1].plot(kind='density',alpha=0.8, color='green',linestyle='--', label='Factual Label 1', ax=axs[1,2])
density_cf[density_cf['target']==1].iloc[:,1].plot(kind='density',alpha=0.8, color='green',label='Counterfactual Label 1', ax=axs[1,2])
density_f[density_f['target']==0].iloc[:,1].plot(kind='density',alpha=0.8, color='blue',linestyle='--', label='Factual Label 0', ax=axs[1,2])
density_cf[density_cf['target']==0].iloc[:,1].plot(kind='density',alpha=0.8,color='blue',label='Counterfactual Label 0', ax=axs[1,2])


###################################### NCI1 ############################################
prefix = 'val_nci1'
folder = f'/home/andab/work/counterfactual_graph_generation/data/predictions/{prefix}_distribution_evaluation/'

mode = 'node_count'
den_cf=pd.read_csv(folder + f'{prefix}_counterfactual_{mode}.csv')
den_f=pd.read_csv(folder + f'{prefix}_factual_{mode}.csv')

mode = 'shannon_entropy'
se_cf=pd.read_csv(folder + f'{prefix}_counterfactual_{mode}.csv')
se_f=pd.read_csv(folder + f'{prefix}_factual_{mode}.csv')

mode = 'densities'
density_cf=pd.read_csv(folder + f'{prefix}_counterfactual_{mode}.csv')
density_f=pd.read_csv(folder + f'{prefix}_factual_{mode}.csv')

# Node count
den_f[den_f['prediction']==1].Number_of_nodes.plot(kind='density',alpha=0.8, color='green',linestyle='--', label='Factual Label 1', ax=axs[2,0])
den_cf[den_cf['prediction']==1].Number_of_nodes.plot(kind='density',alpha=0.8, color='green',label='Counterfactual Label 1', ax=axs[2,0])
den_f[den_f['prediction']==0].Number_of_nodes.plot(kind='density',alpha=0.8, color='blue',linestyle='--', label='Factual Label 0', ax=axs[2,0])
den_cf[den_cf['prediction']==0].Number_of_nodes.plot(kind='density',alpha=0.8,xlabel='Nr Nodes',color='blue',label='Counterfactual Label 0', ax=axs[2,0])

# Shannon Entropy
se_f[se_f['target']==1].iloc[:,1].plot(kind='density',alpha=0.8, color='green',linestyle='--', label='Factual Label 1', ax=axs[2,1])
se_cf[se_cf['target']==1].iloc[:,1].plot(kind='density',alpha=0.8, color='green',label='Counterfactual Label 1', ax=axs[2,1])
se_f[se_f['target']==0].iloc[:,1].plot(kind='density',alpha=0.8, color='blue',linestyle='--', label='Factual Label 0', ax=axs[2,1])
se_cf[se_cf['target']==0].iloc[:,1].plot(kind='density',alpha=0.8,color='blue',label='Counterfactual Label 0', ax=axs[2,1])

# Density
density_f[density_f['target']==1].iloc[:,1].plot(kind='density',alpha=0.8, color='green',linestyle='--', label='Factual Label 1', ax=axs[2,2])
density_cf[density_cf['target']==1].iloc[:,1].plot(kind='density',alpha=0.8, color='green',label='Counterfactual Label 1', ax=axs[2,2])
density_f[density_f['target']==0].iloc[:,1].plot(kind='density',alpha=0.8, color='blue',linestyle='--', label='Factual Label 0', ax=axs[2,2])
density_cf[density_cf['target']==0].iloc[:,1].plot(kind='density',alpha=0.8,color='blue',label='Counterfactual Label 0', ax=axs[2,2])

axs[0,2].legend(loc="upper right")
axs[0,0].set_ylabel("Aids")
axs[1,0].set_ylabel("Mutagenicity")
axs[2,0].set_ylabel("NCI1")
#plt.legend(loc="upper right")
#plt.savefig('C:/Users/acalissa/OneDrive - Imperial College London/Documents/PostDoc/Students/Andreas/counterfactual/plot/density.pdf')
# Out:
# Text(0, 0.5, 'NCI1')

# %% [markdown]
# ## Mutag

# %%
prefix = 'val_mutagenicity'
folder = f'/home/andab/work/counterfactual_graph_generation/data/predictions/{prefix}_distribution_evaluation/'

mode = 'node_count'
den_cf=pd.read_csv(folder + f'{prefix}_counterfactual_{mode}.csv')
den_f=pd.read_csv(folder + f'{prefix}_factual_{mode}.csv')

mode = 'shannon_entropy'
se_cf=pd.read_csv(folder + f'{prefix}_counterfactual_{mode}.csv')
se_f=pd.read_csv(folder + f'{prefix}_factual_{mode}.csv')

mode = 'densities'
density_cf=pd.read_csv(folder + f'{prefix}_counterfactual_{mode}.csv')
density_f=pd.read_csv(folder + f'{prefix}_factual_{mode}.csv')

# %%
fig, axs = plt.subplots(1,3)
fig.set_size_inches(15,4)

# Node count
den_f[den_f['prediction']==1].Number_of_nodes.plot(kind='density',alpha=0.8, color='green',linestyle='--', label='Factual Label 1', ax=axs[0])
den_cf[den_cf['prediction']==1].Number_of_nodes.plot(kind='density',alpha=0.8, color='green',label='Counterfactual Label 1', ax=axs[0])
den_f[den_f['prediction']==0].Number_of_nodes.plot(kind='density',alpha=0.8, color='blue',linestyle='--', label='Factual Label 0', ax=axs[0])
den_cf[den_cf['prediction']==0].Number_of_nodes.plot(kind='density',alpha=0.8,xlabel='Nr Nodes',color='blue',label='Counterfactual Label 0', ax=axs[0], title='Node Count Distribution')

# Shannon Entropy
se_f[se_f['target']==1].iloc[:,1].plot(kind='density',alpha=0.8, color='green',linestyle='--', label='Factual Label 1', ax=axs[1])
se_cf[se_cf['target']==1].iloc[:,1].plot(kind='density',alpha=0.8, color='green',label='Counterfactual Label 1', ax=axs[1])
se_f[se_f['target']==0].iloc[:,1].plot(kind='density',alpha=0.8, color='blue',linestyle='--', label='Factual Label 0', ax=axs[1])
se_cf[se_cf['target']==0].iloc[:,1].plot(kind='density',alpha=0.8,color='blue',label='Counterfactual Label 0', ax=axs[1], title='Shannon Entropy Distribution')

# Density
density_f[density_f['target']==1].iloc[:,1].plot(kind='density',alpha=0.8, color='green',linestyle='--', label='Factual Label 1', ax=axs[2])
density_cf[density_cf['target']==1].iloc[:,1].plot(kind='density',alpha=0.8, color='green',label='Counterfactual Label 1', ax=axs[2])
density_f[density_f['target']==0].iloc[:,1].plot(kind='density',alpha=0.8, color='blue',linestyle='--', label='Factual Label 0', ax=axs[2])
density_cf[density_cf['target']==0].iloc[:,1].plot(kind='density',alpha=0.8,color='blue',label='Counterfactual Label 0', ax=axs[2], title='Graph Density Distribution')

plt.legend(loc="upper right")
#plt.savefig('C:/Users/acalissa/OneDrive - Imperial College London/Documents/PostDoc/Students/Andreas/counterfactual/plot/density.pdf')

# %% [markdown]
# ## NCI1

# %%
prefix = 'val_nci1'
folder = f'/home/andab/work/counterfactual_graph_generation/data/predictions/{prefix}_distribution_evaluation/'

mode = 'node_count'
den_cf=pd.read_csv(folder + f'{prefix}_counterfactual_{mode}.csv')
den_f=pd.read_csv(folder + f'{prefix}_factual_{mode}.csv')

mode = 'shannon_entropy'
se_cf=pd.read_csv(folder + f'{prefix}_counterfactual_{mode}.csv')
se_f=pd.read_csv(folder + f'{prefix}_factual_{mode}.csv')

mode = 'densities'
density_cf=pd.read_csv(folder + f'{prefix}_counterfactual_{mode}.csv')
density_f=pd.read_csv(folder + f'{prefix}_factual_{mode}.csv')

# %%
fig, axs = plt.subplots(1,3)
fig.set_size_inches(15,4)

# Node count
den_f[den_f['prediction']==1].Number_of_nodes.plot(kind='density',alpha=0.8, color='green',linestyle='--', label='Factual Label 1', ax=axs[0])
den_cf[den_cf['prediction']==1].Number_of_nodes.plot(kind='density',alpha=0.8, color='green',label='Counterfactual Label 1', ax=axs[0])
den_f[den_f['prediction']==0].Number_of_nodes.plot(kind='density',alpha=0.8, color='blue',linestyle='--', label='Factual Label 0', ax=axs[0])
den_cf[den_cf['prediction']==0].Number_of_nodes.plot(kind='density',alpha=0.8,xlabel='Nr Nodes',color='blue',label='Counterfactual Label 0', ax=axs[0], title='Node Count Distribution')

# Shannon Entropy
se_f[se_f['target']==1].iloc[:,1].plot(kind='density',alpha=0.8, color='green',linestyle='--', label='Factual Label 1', ax=axs[1])
se_cf[se_cf['target']==1].iloc[:,1].plot(kind='density',alpha=0.8, color='green',label='Counterfactual Label 1', ax=axs[1])
se_f[se_f['target']==0].iloc[:,1].plot(kind='density',alpha=0.8, color='blue',linestyle='--', label='Factual Label 0', ax=axs[1])
se_cf[se_cf['target']==0].iloc[:,1].plot(kind='density',alpha=0.8,color='blue',label='Counterfactual Label 0', ax=axs[1], title='Shannon Entropy Distribution')

# Density
density_f[density_f['target']==1].iloc[:,1].plot(kind='density',alpha=0.8, color='green',linestyle='--', label='Factual Label 1', ax=axs[2])
density_cf[density_cf['target']==1].iloc[:,1].plot(kind='density',alpha=0.8, color='green',label='Counterfactual Label 1', ax=axs[2])
density_f[density_f['target']==0].iloc[:,1].plot(kind='density',alpha=0.8, color='blue',linestyle='--', label='Factual Label 0', ax=axs[2])
density_cf[density_cf['target']==0].iloc[:,1].plot(kind='density',alpha=0.8,color='blue',label='Counterfactual Label 0', ax=axs[2], title='Graph Density Distribution')

plt.legend(loc="upper right")
#plt.savefig('C:/Users/acalissa/OneDrive - Imperial College London/Documents/PostDoc/Students/Andreas/counterfactual/plot/density.pdf')

# %% [markdown]
# ## Logitic regression on node count

# %%
import sklearn
from sklearn.linear_model import LogisticRegression
den_f
# Out:
#      Unnamed: 0  Number_of_nodes  prediction  target
# 0             0             11.0           1       1
# 1             1             11.0           1       1
# 2             2              9.0           1       1
# 3             3              9.0           1       1
# 4             4              8.0           1       1
# ..          ...              ...         ...     ...
# 158         158             18.0           0       0
# 159         159             10.0           1       1
# 160         160             21.0           0       0
# 161         161              7.0           1       1
# 162         162              9.0           1       1
#
# [163 rows x 4 columns]

# %%
model = LogisticRegression(solver='newton-cholesky')
model.fit(np.array(den_f['Number_of_nodes']).reshape(-1,1), np.array(den_f['target']).reshape(-1,1))
pred_prob = model.predict_proba(np.array(range(1,31)).reshape(-1,1))
# Out:
# /home/andab/.conda/envs/cfg/lib/python3.10/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
plt.scatter(den_f['Number_of_nodes'], den_f['target'])
plt.plot(pred_prob[:,1], c='red')
